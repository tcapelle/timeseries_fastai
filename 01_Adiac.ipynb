# %%
from timeseries_fastai.imports import *
from timeseries_fastai.data import *
from timeseries_fastai.core import *
from timeseries_fastai.models import *

# %%
PATH = Path.cwd()

# %% [markdown]
# We can Load the supplied Adiac

# %%
df_train, df_test = load_df_ucr(PATH, 'Adiac')
# Out:
# Loading files from: /home/tcapelle/SteadySun/timeseries_fastai/Adiac

# %% [markdown]
# Bonjour

# %%
df_train.head()
# Out:
#        att1      att2      att3      att4      att5      att6      att7  \
# 0  1.598007  1.599439  1.570529  1.550474  1.507371  1.434341  1.368986
# 1  1.701146  1.670645  1.618884  1.546805  1.475469  1.391209  1.305882
# 2  1.722342  1.695329  1.656946  1.606312  1.511824  1.414148  1.313688
# 3  1.726263  1.659836  1.573108  1.496264  1.409070  1.332443  1.245742
# 4  1.778976  1.761203  1.703084  1.610572  1.492088  1.368654  1.244761
#
#        att8      att9     att10  ...    att168    att169    att170    att171  \
# 0  1.305294  1.210305  1.116653  ...  1.120906  1.217175  1.312530  1.402920
# 1  1.237313  1.153414  1.069690  ...  1.012163  1.097360  1.182578  1.266291
# 2  1.213234  1.112978  1.015081  ...  1.065598  1.164750  1.263924  1.364303
# 3  1.158882  1.073361  0.987165  ...  1.114440  1.199608  1.275380  1.362258
# 4  1.120900  1.010762  0.900168  ...  1.165685  1.285657  1.408878  1.507983
#
#      att172    att173    att174    att175    att176  target
# 0  1.481043  1.521012  1.564154  1.570855  1.592890   b'22'
# 1  1.350571  1.435160  1.519737  1.602518  1.670190   b'28'
# 2  1.463511  1.547307  1.641809  1.694973  1.708488   b'21'
# 3  1.448567  1.535131  1.622158  1.707838  1.739027   b'15'
# 4  1.623643  1.713606  1.766389  1.783633  1.758625    b'2'
#
# [5 rows x 177 columns]

# %%
df_train.tail()
# Out:
#          att1      att2      att3      att4      att5      att6      att7  \
# 385  1.670599  1.655859  1.610092  1.525893  1.440673  1.356233  1.271895
# 386  1.691787  1.662870  1.618478  1.542548  1.453737  1.363733  1.272630
# 387  2.595598  2.625063  2.423959  2.245083  2.332734  2.081564  1.853862
# 388  1.659900  1.644147  1.593779  1.536218  1.456986  1.371655  1.287932
# 389  1.726629  1.728881  1.711699  1.652899  1.597780  1.524009  1.453757
#
#          att8      att9     att10  ...    att168    att169    att170  \
# 385  1.187667  1.102549  1.019581  ...  1.055332  1.138088  1.222857
# 386  1.183061  1.093747  1.005159  ...  1.079268  1.168986  1.257817
# 387  1.649852  1.469948  1.326733  ...  1.221375  1.389820  1.586436
# 388  1.201311  1.113499  1.028015  ...  1.084095  1.169743  1.256185
# 389  1.343776  1.255905  1.149512  ...  1.053883  1.161763  1.257491
#
#        att171    att172    att173    att174    att175    att176  target
# 385  1.307347  1.391835  1.461304  1.545888  1.629884  1.670952   b'31'
# 386  1.350585  1.440217  1.528335  1.604386  1.656697  1.682137   b'33'
# 387  1.815561  1.852951  1.845519  2.144000  2.128894  2.117635    b'6'
# 388  1.343048  1.428322  1.512527  1.579867  1.636902  1.660197   b'28'
# 389  1.347004  1.434941  1.533283  1.596369  1.640333  1.698814   b'25'
#
# [5 rows x 177 columns]

# %%
len(df_train)
# Out:
# 390

# %%
x_cols = df_train.columns[0:-1].to_list()

# %%
dls = TSDataLoaders.from_dfs(df_train, df_test, x_cols=x_cols, label_col='target', bs=16)

# %%
dls.show_batch()

# %%
resnet = create_resnet(1, dls.c)

# %%
learn = Learner(dls, resnet, metrics=[accuracy])

# %%
learn.fit_one_cycle(5, 1e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.052827</td>
#       <td>3.862076</td>
#       <td>0.084399</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.702552</td>
#       <td>3.423679</td>
#       <td>0.158568</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.392180</td>
#       <td>2.412601</td>
#       <td>0.283887</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.126421</td>
#       <td>1.929778</td>
#       <td>0.450128</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.891571</td>
#       <td>1.693967</td>
#       <td>0.572890</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix(figsize=(10,10))
